# %% [markdown]
# # Core - Sakila

# %%
import pymysql
import pandas as pd
pymysql.install_as_MySQLdb()

# %%
from sqlalchemy import create_engine

# %%
connection = "mysql+pymysql://root:root@localhost/sakila"

# %%
engine = create_engine(connection)

# %%
engine
# Out:
# Engine(mysql+pymysql://root:***@localhost/sakila)

# %%
q = """
SELECT * 
FROM country;
"""
pd.read_sql(q, engine)
# Out:
#      country_id               country         last_update
# 0             1           Afghanistan 2006-02-14 12:44:00
# 1             2               Algeria 2006-02-14 12:44:00
# 2             3        American Samoa 2006-02-14 12:44:00
# 3             4                Angola 2006-02-14 12:44:00
# 4             5              Anguilla 2006-02-14 12:44:00
# ..          ...                   ...                 ...
# 104         105               Vietnam 2006-02-14 12:44:00
# 105         106  Virgin Islands, U.S. 2006-02-14 12:44:00
# 106         107                 Yemen 2006-02-14 12:44:00
# 107         108            Yugoslavia 2006-02-14 12:44:00
# 108         109                Zambia 2006-02-14 12:44:00
#
# [109 rows x 3 columns]

# %% [markdown]
# ![png](sakila-db-model.png)

# %% [markdown]
# # 1. What query would you run to get all the customers inside city_id = 312? Your query should return the customers' first name, last name, email, address, and city.

# %%
a = """
SELECT customer.first_name, customer.last_name, customer.email, address.city_id, address.address
FROM customer
JOIN address
ON customer.address_id = address.address_id
WHERE address.city_id= '312'
"""
pd.read_sql(a, engine)
# Out:
#   first_name last_name                              email  city_id  \
# 0     MATTIE   HOFFMAN  MATTIE.HOFFMAN@sakilacustomer.org      312
# 1      CECIL     VINES     CECIL.VINES@sakilacustomer.org      312
#
#               address
# 0   1497 Yuzhou Drive
# 1  548 Uruapan Street

# %% [markdown]
# # 2. What query would you run to get all comedy films? Note that the genre is called the category in this schema.  Your query should return film title, description, release year, rating, and special features

# %%
b = """
SELECT *
FROM film
JOIN film_category
ON film.film_id = film_category.film_id
JOIN category
ON film_category.category_id = category.category_id
WHERE category.name = 'comedy';
"""
pd.read_sql(b,engine)
# Out:
#     film_id                    title  \
# 0         7          AIRPLANE SIERRA
# 1        28              ANTHEM LUKE
# 2        99      BRINGING HYSTERICAL
# 3       119            CAPER MOTIONS
# 4       127            CAT CONEHEADS
# 5       159              CLOSER BANG
# 6       178   CONNECTION MICROCOSMOS
# 7       182           CONTROL ANTHEM
# 8       188               CRAZY HOME
# 9       202         DADDY PITTSBURGH
# 10      242             DOOM DANCING
# 11      247          DOWNHILL ENOUGH
# 12      265              DYING MAKER
# 13      276           ELEMENT FREDDY
# 14      308            FERRIS MOTHER
# 15      317    FIREBALL PHILADELPHIA
# 16      324    FLINTSTONES HAPPINESS
# 17      332    FRANKENSTEIN STRANGER
# 18      335        FREEDOM CLEOPATRA
# 19      365               GOLD RIVER
# 20      385          GROUNDHOG UNCUT
# 21      388            GUNFIGHT MOON
# 22      404            HATE HANDICAP
# 23      410           HEAVEN FREEDOM
# 24      413             HEDWIG ALTER
# 25      443         HURRICANE AFFAIR
# 26      444            HUSTLER PARTY
# 27      478               JAWS HARRY
# 28      502            KNOCK WARLOCK
# 29      522             LIFE TWISTED
# 30      524               LION UNCUT
# 31      529          LONELY ELEPHANT
# 32      555          MALLRATS UNITED
# 33      568        MEMENTO ZOOLANDER
# 34      604               MULAN MOON
# 35      613            MYSTIC TRUMAN
# 36      638      OPERATION OPERATION
# 37      657         PARADISE SABRINA
# 38      660              PARTY KNOCK
# 39      672           PERFECT GROOVE
# 40      680          PINOCCHIO SIMON
# 41      704              PURE RUNNER
# 42      754         RUSHMORE MERMAID
# 43      756         SADDLE ANTITRUST
# 44      765              SATURN NAME
# 45      774           SEARCHERS WAIT
# 46      814           SNATCH SLIPPER
# 47      837              STAGE WORLD
# 48      857        STRICTLY SCARFACE
# 49      858            SUBMARINE BED
# 50      871           SWEDEN SHINING
# 51      905  TRAINSPOTTING STRANGERS
# 52      906             TRAMP OTHERS
# 53      932            VALLEY PACKER
# 54      938        VELVET TERMINATOR
# 55      939        VERTIGO NORTHWEST
# 56      978            WISDOM WORKER
# 57     1000                ZORRO ARK
#
#                                           description  release_year  \
# 0   A Touching Saga of a Hunter And a Butler who m...          2006
# 1   A Touching Panorama of a Waitress And a Woman ...          2006
# 2   A Fateful Saga of a A Shark And a Technical Wr...          2006
# 3   A Fateful Saga of a Moose And a Car who must P...          2006
# 4   A Fast-Paced Panorama of a Girl And a A Shark ...          2006
# 5   A Unbelieveable Panorama of a Frisbee And a Hu...          2006
# 6   A Fateful Documentary of a Crocodile And a Hus...          2006
# 7   A Fateful Documentary of a Robot And a Student...          2006
# 8   A Fanciful Panorama of a Boy And a Woman who m...          2006
# 9   A Epic Story of a A Shark And a Student who mu...          2006
# 10  A Astounding Panorama of a Car And a Mad Scien...          2006
# 11  A Emotional Tale of a Pastry Chef And a Forens...          2006
# 12  A Intrepid Tale of a Boat And a Monkey who mus...          2006
# 13  A Awe-Inspiring Reflection of a Waitress And a...          2006
# 14  A Touching Display of a Frisbee And a Frisbee ...          2006
# 15  A Amazing Yarn of a Dentist And a A Shark who ...          2006
# 16  A Fateful Story of a Husband And a Moose who m...          2006
# 17  A Insightful Character Study of a Feminist And...          2006
# 18  A Emotional Reflection of a Dentist And a Mad ...          2006
# 19  A Taut Documentary of a Database Administrator...          2006
# 20  A Brilliant Panorama of a Astronaut And a Tech...          2006
# 21  A Epic Reflection of a Pastry Chef And a Explo...          2006
# 22  A Intrepid Reflection of a Mad Scientist And a...          2006
# 23  A Intrepid Story of a Butler And a Car who mus...          2006
# 24  A Action-Packed Yarn of a Womanizer And a Lumb...          2006
# 25  A Lacklusture Epistle of a Database Administra...          2006
# 26  A Emotional Reflection of a Sumo Wrestler And ...          2006
# 27  A Thrilling Display of a Database Administrato...          2006
# 28  A Unbelieveable Story of a Teacher And a Boat ...          2006
# 29  A Thrilling Reflection of a Teacher And a Comp...          2006
# 30  A Intrepid Display of a Pastry Chef And a Cat ...          2006
# 31  A Intrepid Story of a Student And a Dog who mu...          2006
# 32  A Thrilling Yarn of a Waitress And a Dentist w...          2006
# 33  A Touching Epistle of a Squirrel And a Explore...          2006
# 34  A Emotional Saga of a Womanizer And a Pioneer ...          2006
# 35  A Epic Yarn of a Teacher And a Hunter who must...          2006
# 36  A Intrepid Character Study of a Man And a Fris...          2006
# 37  A Intrepid Yarn of a Car And a Moose who must ...          2006
# 55            1                 None                4         2.99      90
# 56            1                 None                3         0.99      98
# 57            1                 None                3         4.99      50
#
#     replacement_cost rating  \
# 0              28.99  PG-13
# 1              16.99  PG-13
# 2              14.99     PG
# 3              22.99      G
# 4              14.99      G
# 5              12.99      R
# 6              25.99      G
# 7               9.99      G
# 8              24.99     PG
# 9              26.99      G
# 10             13.99      R
# 11             19.99      G
# 12             28.99     PG
# 13             28.99  NC-17
# 14             13.99     PG
# 15             25.99     PG
# 16             11.99  PG-13
# 17             16.99  NC-17
# 18             23.99  PG-13
# 19             21.99      R
# 20             26.99  PG-13
# 21             16.99  NC-17
# 22             26.99     PG
# 23             19.99     PG
# 24             16.99  NC-17
# 25             11.99     PG
# 26             22.99  NC-17
# 27             10.99      G
# 28             21.99  PG-13
# 29              9.99  NC-17
# 30             13.99     PG
# 31             12.99      G
# 32             25.99     PG
# 33             11.99  NC-17
# 34             10.99      G
# 35             19.99  NC-17
# 36             23.99      G
# 37             12.99  PG-13
# 38             11.99     PG
# 39             17.99  PG-13
# 40             21.99     PG
# 41             25.99  NC-17
# 42             17.99  PG-13
# 43             10.99  PG-13
# 44             18.99      R
# 45             22.99  NC-17
# 46             15.99     PG
# 47             19.99     PG
# 48             24.99  PG-13
# 49             21.99      R
# 50             19.99     PG
# 51             10.99  PG-13
# 52             27.99     PG
# 53             21.99      G
# 54             14.99      R
# 55             17.99      R
# 56             12.99      R
# 57             18.99  NC-17
#
#                                      special_features         last_update  \
# 0                             Trailers,Deleted Scenes 2006-02-14 13:03:42
# 1                    Deleted Scenes,Behind the Scenes 2006-02-14 13:03:42
# 2                                            Trailers 2006-02-14 13:03:42
# 3                Trailers,Commentaries,Deleted Scenes 2006-02-14 13:03:42
# 4                         Commentaries,Deleted Scenes 2006-02-14 13:03:42
# 5                          Trailers,Behind the Scenes 2006-02-14 13:03:42
# 6                    Deleted Scenes,Behind the Scenes 2006-02-14 13:03:42
# 7                                        Commentaries 2006-02-14 13:03:42
# 8                         Commentaries,Deleted Scenes 2006-02-14 13:03:42
# 9                    Deleted Scenes,Behind the Scenes 2006-02-14 13:03:42
# 10                              Trailers,Commentaries 2006-02-14 13:03:42
# 11               Trailers,Commentaries,Deleted Scenes 2006-02-14 13:03:42
# 12                                  Behind the Scenes 2006-02-14 13:03:42
# 13                     Commentaries,Behind the Scenes 2006-02-14 13:03:42
# 14          Trailers,Deleted Scenes,Behind the Scenes 2006-02-14 13:03:42
# 15            Trailers,Commentaries,Behind the Scenes 2006-02-14 13:03:42
# 16  Trailers,Commentaries,Deleted Scenes,Behind th... 2006-02-14 13:03:42
# 17                   Deleted Scenes,Behind the Scenes 2006-02-14 13:03:42
# 18            Trailers,Commentaries,Behind the Scenes 2006-02-14 13:03:42
# 19  Trailers,Commentaries,Deleted Scenes,Behind th... 2006-02-14 13:03:42
# 20  Trailers,Commentaries,Deleted Scenes,Behind th... 2006-02-14 13:03:42
# 21                   Deleted Scenes,Behind the Scenes 2006-02-14 13:03:42
# 22            Trailers,Commentaries,Behind the Scenes 2006-02-14 13:03:42
# 23                                       Commentaries 2006-02-14 13:03:42
# 24            Trailers,Commentaries,Behind the Scenes 2006-02-14 13:03:42
# 25            Trailers,Commentaries,Behind the Scenes 2006-02-14 13:03:42
# 26            Trailers,Commentaries,Behind the Scenes 2006-02-14 13:03:42
# 27                                     Deleted Scenes 2006-02-14 13:03:42
# 28                                           Trailers 2006-02-14 13:03:42
# 29                        Commentaries,Deleted Scenes 2006-02-14 13:03:42
# 30                            Trailers,Deleted Scenes 2006-02-14 13:03:42
# 31  Trailers,Commentaries,Deleted Scenes,Behind th... 2006-02-14 13:03:42
# 32               Trailers,Commentaries,Deleted Scenes 2006-02-14 13:03:42
# 33                                  Behind the Scenes 2006-02-14 13:03:42
# 34                                  Behind the Scenes 2006-02-14 13:03:42
# 35                     Commentaries,Behind the Scenes 2006-02-14 13:03:42
# 36  Trailers,Commentaries,Deleted Scenes,Behind th... 2006-02-14 13:03:42
# 37      Commentaries,Deleted Scenes,Behind the Scenes 2006-02-14 13:03:42
# 38                         Trailers,Behind the Scenes 2006-02-14 13:03:42
# 39      Commentaries,Deleted Scenes,Behind the Scenes 2006-02-14 13:03:42
# 40                     Commentaries,Behind the Scenes 2006-02-14 13:03:42
# 41                            Trailers,Deleted Scenes 2006-02-14 13:03:42
# 42               Trailers,Commentaries,Deleted Scenes 2006-02-14 13:03:42
# 43                            Trailers,Deleted Scenes 2006-02-14 13:03:42
# 44  Trailers,Commentaries,Deleted Scenes,Behind th... 2006-02-14 13:03:42
# 45  Trailers,Commentaries,Deleted Scenes,Behind th... 2006-02-14 13:03:42
# 46                                       Commentaries 2006-02-14 13:03:42
# 47                     Commentaries,Behind the Scenes 2006-02-14 13:03:42
# 48      Commentaries,Deleted Scenes,Behind the Scenes 2006-02-14 13:03:42
# 49                                           Trailers 2006-02-14 13:03:42
# 50                   Deleted Scenes,Behind the Scenes 2006-02-14 13:03:42
#
# 51      905            5 2006-02-14 13:07:09            5  Comedy
# 52      906            5 2006-02-14 13:07:09            5  Comedy
# 53      932            5 2006-02-14 13:07:09            5  Comedy
# 54      938            5 2006-02-14 13:07:09            5  Comedy
# 55      939            5 2006-02-14 13:07:09            5  Comedy
# 56      978            5 2006-02-14 13:07:09            5  Comedy
# 57     1000            5 2006-02-14 13:07:09            5  Comedy
#
#            last_update
# 0  2006-02-14 12:46:27
# 1  2006-02-14 12:46:27
# 2  2006-02-14 12:46:27
# 3  2006-02-14 12:46:27
# 4  2006-02-14 12:46:27
# 5  2006-02-14 12:46:27
# 6  2006-02-14 12:46:27
# 7  2006-02-14 12:46:27
# 8  2006-02-14 12:46:27
# 9  2006-02-14 12:46:27
# 10 2006-02-14 12:46:27
# 11 2006-02-14 12:46:27
# 12 2006-02-14 12:46:27
# 13 2006-02-14 12:46:27
# 14 2006-02-14 12:46:27
# 15 2006-02-14 12:46:27
# 16 2006-02-14 12:46:27
# 17 2006-02-14 12:46:27
# 18 2006-02-14 12:46:27
# 19 2006-02-14 12:46:27
# 20 2006-02-14 12:46:27
# 21 2006-02-14 12:46:27
# 22 2006-02-14 12:46:27
# 23 2006-02-14 12:46:27
# 24 2006-02-14 12:46:27
# 25 2006-02-14 12:46:27
# 26 2006-02-14 12:46:27
# 27 2006-02-14 12:46:27
# 28 2006-02-14 12:46:27
# 29 2006-02-14 12:46:27
# 30 2006-02-14 12:46:27
# 31 2006-02-14 12:46:27
# 32 2006-02-14 12:46:27
# 33 2006-02-14 12:46:27
# 34 2006-02-14 12:46:27
# 35 2006-02-14 12:46:27
# 36 2006-02-14 12:46:27
# 37 2006-02-14 12:46:27
# 38 2006-02-14 12:46:27
# 39 2006-02-14 12:46:27
# 40 2006-02-14 12:46:27
# 41 2006-02-14 12:46:27
# 42 2006-02-14 12:46:27
# 43 2006-02-14 12:46:27
# 44 2006-02-14 12:46:27
# 45 2006-02-14 12:46:27
# 46 2006-02-14 12:46:27
# 47 2006-02-14 12:46:27
# 48 2006-02-14 12:46:27
# 49 2006-02-14 12:46:27
# 50 2006-02-14 12:46:27
# 51 2006-02-14 12:46:27
# 52 2006-02-14 12:46:27
# 53 2006-02-14 12:46:27
# 54 2006-02-14 12:46:27
# 55 2006-02-14 12:46:27
# 56 2006-02-14 12:46:27
# 57 2006-02-14 12:46:27

# %% [markdown]
# # 3. What query would you run to get all the films that Johnny Lollobrigida was in? Your query should return the actor's last name, film title, and release year.

# %%
c = """
SELECT actor.last_name, film.title, film.release_year
FROM actor
JOIN film_actor
ON actor.actor_id = film_actor.actor_id
JOIN film
ON film.film_id = film_actor.film_id
WHERE actor.last_name='Lollobrigida';
"""
pd.read_sql(c,engine)
# Out:
#        last_name                 title  release_year
# 0   LOLLOBRIGIDA          AMADEUS HOLY          2006
# 1   LOLLOBRIGIDA      BANGER PINOCCHIO          2006
# 2   LOLLOBRIGIDA      BONNIE HOLOCAUST          2006
# 3   LOLLOBRIGIDA           CHITTY LOCK          2006
# 4   LOLLOBRIGIDA  COMMANDMENTS EXPRESS          2006
# 5   LOLLOBRIGIDA     CONEHEADS SMOOCHY          2006
# 6   LOLLOBRIGIDA      DADDY PITTSBURGH          2006
# 7   LOLLOBRIGIDA       DAISY MENAGERIE          2006
# 8   LOLLOBRIGIDA         ENOUGH RAGING          2006
# 9   LOLLOBRIGIDA     ESCAPE METROPOLIS          2006
# 10  LOLLOBRIGIDA           FIRE WOLVES          2006
# 11  LOLLOBRIGIDA        FRONTIER CABIN          2006
# 12  LOLLOBRIGIDA     GOODFELLAS SALUTE          2006
# 13  LOLLOBRIGIDA    GRAIL FRANKENSTEIN          2006
# 14  LOLLOBRIGIDA        GROOVE FICTION          2006
# 15  LOLLOBRIGIDA          HALL CASSIDY          2006
# 16  LOLLOBRIGIDA          HEAVENLY GUN          2006
# 17  LOLLOBRIGIDA      KRAMER CHOCOLATE          2006
# 18  LOLLOBRIGIDA         LOVE SUICIDES          2006
# 19  LOLLOBRIGIDA      METAL ARMAGEDDON          2006
# 20  LOLLOBRIGIDA       PACIFIC AMISTAD          2006
# 21  LOLLOBRIGIDA      PATTON INTERVIEW          2006
# 22  LOLLOBRIGIDA            POCUS PULP          2006
# 23  LOLLOBRIGIDA   RIDGEMONT SUBMARINE          2006
# 24  LOLLOBRIGIDA   RINGS HEARTBREAKERS          2006
# 25  LOLLOBRIGIDA         SMILE EARRING          2006
# 26  LOLLOBRIGIDA    SOLDIERS EVOLUTION          2006
# 27  LOLLOBRIGIDA        STAR OPERATION          2006
# 28  LOLLOBRIGIDA        SUNRISE LEAGUE          2006

# %% [markdown]
# # 4. What query would you run to get the first and last names of all the actors in the movie titled "Bingo Talented"?

# %%
d = """
SELECT actor.first_name, actor.last_name
FROM actor
JOIN film_actor
ON actor.actor_id = film_actor.actor_id
JOIN film
ON film.film_id = film_actor.film_id
WHERE film.title='Bingo Talented';
"""
pd.read_sql(d,engine)
# Out:
#   first_name    last_name
# 0     GOLDIE        BRODY
# 1    CAMERON         WRAY
# 2       CARY  MCCONAUGHEY
# 3        JON        CHASE
# 4      RENEE         BALL

# %% [markdown]
# # 5. What query would you run to get the customer_id associated with all payments greater than twice the average payment amount? (HINT: use 2* in your query to get twice the amount). Your result should include the customer id and the amount.

# %%
e = """
SELECT customer_id, amount
FROM payment
WHERE amount > 2 * (SELECT
 AVG(amount) FROM payment);
"""
pd.read_sql(e,engine)
# Out:
#      customer_id  amount
# 0              1    9.99
# 1              2   10.99
# 2              3    8.99
# 3              3   10.99
# 4              3    8.99
# ..           ...     ...
# 852          595    9.99
# 853          595   10.99
# 854          597    8.99
# 855          599    9.99
# 856          599    8.99
#
# [857 rows x 2 columns]

# %% [markdown]
# # 6. What query would you run to list the first and last names of the 5 customers who have the highest number(count) of payments? You can title the number of payments as num_payments.

# %%
f = """
SELECT customer.first_name, customer.last_name,
(SELECT COUNT(*)
 FROM payment
 WHERE payment.customer_id = customer.customer_id) AS num_payments
FROM customer
ORDER BY num_payments DESC
LIMIT 5;
"""
pd.read_sql(f,engine)
# Out:
#   first_name last_name  num_payments
# 0    ELEANOR      HUNT            46
# 1       KARL      SEAL            45
# 2     MARCIA      DEAN            42
# 3      CLARA      SHAW            42
# 4      TAMMY   SANDERS            41
